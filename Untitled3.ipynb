# %%
import pandas as pd

# %%
df=pd.read_csv('/content/sports_dataset_cleaned.csv')
df
# Out:
#      Player_ID Player_Name  Gender  Age       Country    Team    Position  \
# 0        P9690        Sara     NaN   27        Brazil  Team E     Forward
# 1        P8755        Sara     NaN   35           USA  Team A    Defender
# 2        P9328        John  Female   21       Germany  Team C  Goalkeeper
# 3        P7544        John    Male   44       Germany  Team D    Defender
# 4        P3007        Amit    Male   40           USA  Team E     Batsman
# ...        ...         ...     ...  ...           ...     ...         ...
# 5374     P5944       Priya   Other   19  South Africa  Team E    Defender
# 5375     P9527        Mike    Male   33           USA  Team D    Defender
# 5376     P9713         Liu  Female   38        Xrazil  Team A      Bowler
# 5377     P3686        John   Other   36       Germany  Team B     Forward
# 5378     P4860        Mike  Female   16        Brazil  Team A  Goalkeeper
#
#       Sport_Type Match_ID    Tournament  ...    Bonus Sponsorship_Amount  \
# ...
